# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)                                               | Output
# |  | -
# | 1.1  |The data from the car sensors e.g camaras. radors, gps  | Generates steering commands, braking, accelaration
# | 1.2  |The viewing history data                                | Provides recommendations for movies or TV shows
# | 1.3  |It processes the images or scans of a signatures        | The system provides a verification result
# | 1.4  |the system takes medical history, symptoms,X-rays or MRIs.| The system provides a diagnosis or prediction of a medical condition.
#
# Self-driving Car (1.1):
#
# For self-driving cars they use various sensors like cameras, lidar, radar, and GPS to understand their surroundings. They also consider internal data, such as the car's speed and engine status so the vechicle can make decisions about driving.
#
# Netflix Recommendation System (1.2):
#
# Netflix has a recommendation system to provide a better experience by suggesting content personalised to the user. Therefore, it looks at your preferences, what you have watched in the past or present, and provides you with the available shows and movies on netlfix.
#
# Signature Recognition (1.3):
#
# For the signature recognition it looks at images or scans of signatures. So when looking at electronic signatures it considers features like pressure, speed, and the angle of the signature and style of writing. This helps in verifying if a signature is genuine.

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1: I would use classification.  As we are putting emails in specific groups, like sorting them into labeled boxes. This is called classification.
#
# * 2.2: I would use regression because when predicting a continous numeric it is like finding a pattern in the past stock prices and trends to predict a specific number for the future. The program learns to estimate and predict a continuous output value.
#
# * 2.3: A classification algorithm is best for this situation because it's similar to training a system to recognize visual features and categorise the images into different species.
#
# * 2.4: For this situation were you want to predict the likelihood of a patient having a particular disease  based on their medical hisotry and diagnostic test result. The most appropriate algorithm would be Classification because we are creating a system that can examine different factors to decide whether a patient has a specific disease.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 I would use unsupervised learning because as we do not have prior knowledge of specific anomaly patterns. Therefore using anomaly detection algorithm like clustering will be able to identify patterns in the data without needing labelled data to discover anomalies, it will discover patterns by its own.
#
# * 3.2 I would use supervised learning because we are predicting customer lifetime value so we can predict an outcome, using transaction data and customer demographics which are the labeled training data, allowing the model to learn from patterns and relationships. Also, as the customer lifetime value is a continuous variable we could also use regression to predict output values.
#
# * 3.3: I would use unsupervised machine learning algorithm because it is ideal for finding and revealing patterns and relationships within a dataset without labeled examples or predefined categories. In this situation we are segmenting customers based on their characteristics therefore, the algorithm will learn and discover these segments on its own.
#
# * 3.4: I would use unsupervised machine learning algorithms for analysing social media posts to categorise them into different themes. This would be best because it will automatically identify patterns and groupings within the unstructured data of social media posts without relying on pre-labeled examples or predefined categories.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# *4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1. I would use semi-supervised machine learning algorithms because most of the transactions are labelled. Using this labeled data can provide guidance to the algorithms to learn from known fraudalent transactions and which are legitimate therefore, it will be understand patterns in the data.
#
# * 4.2: I would use semi-supervised machine learning algorithms because as theres is only small portion of the data is labelled with satisfaction ratings. This allows the algorithm to get a broader understanding of dataset by ultilising the lebelled and unlabelled data to gain insights on the data.
#
# * 4.3: I would not use semi-supervised machine learning algorithms because majority of emails are already labelled therefore, supervised learning would better suit this situation to create or enchance the model to detect spam more effectively.
#
# * 4.4: I would not use semi-supervised machine learning algorithms because when predicting whether credit card applicants are likely to default based on their financial and credit details, a supervised learning approach is better because We have enough labeled data by looking at the applicants with known default outcomes. You can train a reliable model without needing semi-supervised learning because in supervised learning you use labeled examples to make accurate predictions. Also, this method fits well for standard prediction tasks like assessing default probability.
